# %%
import matplotlib.pyplot as plt

# %%
labels = ['Group1', 'Group2', 'Group3', 'Group4','Group5']
men_age = [20, 35, 30, 35,20]
women_age = [25, 32, 34, 20,25]
ax.bar(labels, men_age, label='Men')

ax.bar(labels,women_age,bottom=men_age, label='Women')
fig, ax = plt.subplots()

ax.set_ylabel('Age')
ax.set_xlabel('Group Number')
ax.set_title('Gender Ratio by group')

ax.legend()
plt.show()
# Out:
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_680\1564530757.py:13: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.bar(labels, men_age, label='Men')

ax.bar(labels,women_age,bottom=men_age, label='Women')


ax.set_ylabel('Age')
ax.set_xlabel('Group Number')
ax.set_title('Gender Ratio by group')

ax.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

classes = ["Python", "R", "AI", "ML", "DS"]
class1_students = [30, 10, 20, 25, 10]
class2_Students = [40, 5, 20, 10, 20]

class_index = np.arange(len(classes))
width = 0.2

plt.bar(class_index, class1_students, width, label="class1 Students")
plt.bar(class_index+width, class2_Students, width, label ="class2 Students")

plt.xticks(class_index+width,classes)

plt.title("Bar chart of CLASSES")
plt.xlabel("Classes")
plt.ylabel("No. of students")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

classes = ["Python", "R", "AI", "ML", "DS"]
class1_students = [30, 10, 20, 25, 10]
class2_Students = [40, 5, 20, 10, 20]

class_index = np.arange(len(classes))
width = 0.2

plt.barh(class_index, class1_students, width, label="class1 Students")
plt.barh(class_index+width, class2_Students, width, label ="class2 Students")

plt.xticks(class_index+width,classes)

plt.title("Bar chart of CLASSES")
plt.xlabel("Classes")
plt.ylabel("No. of students")
plt.show()

# %%
import matplotlib.pyplot as plt

sub={'python':1, 'java':2, 'c++':6, 'javascript':8}
names = list(sub.keys())
values = list(sub.values())    
plt.bar(names,values)
plt.show()

# %%
import matplotlib.pyplot as plt

sub={'python':1, 'java':2, 'c++':6, 'javascript':8}
names = list(sub.keys())
values = list(sub.values())    
plt.scatter(names,values)
plt.show()

# %%
import matplotlib.pyplot as plt

sub={'python':1, 'java':2, 'c++':6, 'javascript':8}
names = list(sub.keys())
values = list(sub.values())
x = 100
plt.scatter(names,values,x,marker= r'$\clubsuit$')
            
plt.show()

# %%
import matplotlib.pyplot as plt

sub={'python':1, 'java':2, 'c++':6, 'javascript':8}
names = list(sub.keys())
values = list(sub.values())
x = 400
plt.scatter(names,values,x,marker= r'$\diamond$')
    
plt.show()

# %%
import matplotlib.pyplot as plt

sub={'python':1, 'java':2, 'c++':6, 'javascript':8}
names = list(sub.keys())
values = list(sub.values())
x = 123
plt.plot(names,values,x,marker= r'$\diamond$')
    
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as num

x_axis = num.array([0,5,10,15,20,25,30])
plt.plot(x_axis, x_axis*2)
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
# Out:
# Text(0, 0.5, 'Y Axis')

# %%
plt.plot(x_axis, x_axis*2,'red',label='x=y*2')
plt.legend()
plt.show()

# %%
y_axis = x_axis**2
empty_canvas = plt.figure()
create_axis = empty_canvas.add_axes([1, 0, 0, 1]) 

create_axis.plot(x_axis, y_axis, 'b')



create_axis = empty_canvas.add_axes([1, 0, 1, 1]) 

create_axis.plot(x_axis, y_axis, 'b', label = "x = x**2")
create_axis.plot(x_axis, y_axis+(x_axis*3), 'g', label = "x = y+(x*3)")

create_axis.legend(loc=0)

# %%
import numpy as np
x = np.random.rand(200)>0.7
x
barprops = dict(aspect='auto', cmap='binary')
fig = plt.figure()
ax1= fig.add_axes([0.2,0.2,0.8,0.2])
ax1.imshow(x.reshape((1,-1)), **barprops)

# %%
# %pip install qrcode
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting qrcode
#   Downloading qrcode-8.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: colorama in c:\users\victus\appdata\roaming\python\python313\site-packages (from qrcode) (0.4.6)
# Downloading qrcode-8.2-py3-none-any.whl (45 kB)
# Installing collected packages: qrcode
# Successfully installed qrcode-8.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import qrcode 
url = "https://www.facebook.com/"
img = qrcode.make(url)
img.save("qr.png")
img.show()

# %%
import matplotlib.pyplot as plt 
import matplotlib.patches as patches
image = plt.imread('god.jpg')
fig,ax = plt.subplots()
im = ax.imshow(image)
patch= patches.Cirle((600,600),radius=300,transform=ax.transData)
im.set_clip_path(patch)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 6
#       4 fig,ax = plt.subplots()
#       5 im = ax.imshow(image)
# ----> 6 patch= patches.Cirle((600,600),radius=300,transform=ax.transData)
#       7 im.set_clip_path(patch)
#
# AttributeError: module 'matplotlib.patches' has no attribute 'Cirle'

# %%
import numpy as np
all_data = [np.random.normal(0,x,size=20)for x in range(1,5)]
all_data
# Out:
# [array([ 1.27036569,  0.55015165,  0.42580437,  0.27205643,  0.25004187,
#          0.6845827 ,  0.75994894,  0.85963499,  0.39848293, -0.55592721,
#          0.77455373,  0.93061355, -0.3668513 , -0.87766859, -0.08756395,
#         -0.21430231, -0.54684595,  0.52760279,  0.55824821, -1.08697689]),
#  array([ 2.07229274,  0.66410067,  0.12063477,  0.21856246, -0.23829359,
#         -0.43564386, -1.64062104, -2.90848193,  1.2792278 ,  0.31206754,
#          0.70323959,  0.06925244, -1.93727985,  3.16971945,  3.0622736 ,
#         -3.28398249,  0.37249461, -1.27935124, -1.49111396, -2.39124915]),
#  array([ 0.27675009, -0.21211499, -4.16530265, -3.18782496,  1.35950491,
#          2.82004585,  1.09536497, -2.13093907, -1.49061434,  0.97279249,
#         -0.76516574, -3.1358176 , -0.16912858,  2.81992214,  0.43428344,
#         -0.24700185, -2.87812241,  3.76568248,  2.14532182, -0.36878138]),
#  array([-3.90790974, -3.26548998,  2.66869144,  3.76236054,  2.27601374,
#         -6.88082528,  3.88556606, -3.776297  ,  1.63768276, -2.66346477,
#          2.74894918,  2.08639754, -3.49846475, -8.82269118, -0.21270229,
#         -3.33876629, -5.21336112, -5.61285876,  0.29816208,  3.36445098])]

# %%
import matplotlib.pyplot as plt 
import numpy as np
labels = ['x1','x2','x3','x4']
bplots1 = plt.boxplot(all_data,0,'rs',0,labels=labels)
plt.show()
# Out:
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_492\3945647815.py:4: MatplotlibDeprecationWarning: Passing the notch parameter of boxplot() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   bplots1 = plt.boxplot(all_data,0,'rs',0,labels=labels)
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_492\3945647815.py:4: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   bplots1 = plt.boxplot(all_data,0,'rs',0,labels=labels)

# %%
import matplotlib.pyplot as plt 
import numpy as np
labels = ['x1','x2','x3','x4']
vplots1 = plt.violinplot(all_data)
plt.show()

# %%
import matplotlib.pyplot as plt 
import numpy as np
all_data = [np.random.normal(0,x,size=50)for x in range (1,5)]
labels = ['x1','x2','x3','x4']
fig,axs = plt.subplots(1,2,figsize(12,3))
axs[0].boxplot(all_data,labels=labels)
axs[1].violinplot(all_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 all_data = [np.random.normal(0,x,size=50)for x in range (1,5)]
#       4 labels = ['x1','x2','x3','x4']
# ----> 5 fig,axs = plt.subplots(1,2,figsize(12,3))
#       6 axs[0].boxplot(all_data,labels=labels)
#       7 axs[1].violinplot(all_data)
#
# NameError: name 'figsize' is not defined

# %%
import matplotlib.pyplot as plt
add_data = [np.random.random(100)]
plt.hist(all_data,bins=10)
# Out:
# (array([[ 0.,  0.,  0.,  3., 37., 10.,  0.,  0.,  0.,  0.],
#         [ 0.,  0.,  1.,  8., 22., 13.,  6.,  0.,  0.,  0.],
#         [ 1.,  4.,  2.,  8.,  9., 17.,  7.,  2.,  0.,  0.],
#         [ 3.,  2.,  4., 11., 15.,  4.,  3.,  3.,  2.,  3.]]),
#  array([-10.13427915,  -7.97413904,  -5.81399892,  -3.6538588 ,
#          -1.49371869,   0.66642143,   2.82656155,   4.98670166,
#           7.14684178,   9.3069819 ,  11.46712201]),
#  <a list of 4 BarContainer objects>)

# %%
import matplotlib.pyplot as plt
data = { 'Batch 1':30,'Batch 2':20,'Batch 3':35,'Batch 4':15}
names = list(data.keys())
values = list(data.values())

plt.pie(values,labels=names,autopct='%0.1f%%')
plt.title("Batch Distribution")
plt.savfig("Fig.png",dpi = 300)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 8
#       6 plt.pie(values,labels=names,autopct='%0.1f%%')
#       7 plt.title("Batch Distribution")
# ----> 8 plt.savfig("Fig.png",dpi = 300)
#       9 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'savfig'

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
plt.text(0.1,0.2,r' an euation:$E=mc^2$',fontsize=16)
plt.show()
